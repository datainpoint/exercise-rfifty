# %% [markdown]
# # R 語言的五十道練習
#
# > 流程控制
#
# [數據交點](https://www.datainpoint.com/) | 郭耀仁 <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 第一個程式碼儲存格會將可能用得到的套件以及單元測試 `testthat` 載入。
# - 如果練習題需要載入檔案，檔案與練習題存放在同個資料夾中，意即我們可以指定工作目錄來載入。
# - 練習題已經定義好函數的名稱以及參數名稱，我們只需要寫作主體。
# - 函數名稱下面幾行的註解部分是在描述測試如何進行。
# - 觀察函數名稱下面幾行的註解部分能夠暸解輸入以及預期輸出之間的關係，幫助我們更暸解題目。
# - 在 `### BEGIN SOLUTION` 與 `### END SOLUTION` 這兩個單行註解之間撰寫函數的主體。
# - 可以先在 RStudio 寫出跟預期結果相同的程式後再複製貼上到練習題。
# - 執行測試的方式為點選上方選單的 Kernel -> Restart & Run All -> Restart and Run All Cells。
# - 可以每寫一題就執行測試，也可以全部寫完再執行測試。
# - 練習題閒置超過 10 分鐘會自動斷線，這時只要重新點選練習題連結即可重新啟動。

# %%
library("testthat")

# %% [markdown]
# ## 自行定義函數 `calculate_circle` 能夠將輸入的半徑依照參數 `to` 計算為面積或周長，使用 $\pi = 3.14$。
#
# \begin{equation}
# Area = \pi r^2 \\
# Perimeter = 2 \pi r \\
# \text{where} \; \pi = 3.14
# \end{equation}
#
# - 預期輸入：一個數值向量、一個文字向量。
# - 預期輸出：一個文字向量。

# %%
calculate_circle <- function(r, to) {
    # calculate_circle(3, to='area')
    # [1] 28.26
    # calculate_circle(3, to='perimeter')
    # [1] 18.84
    # calculate_circle(4, to='area')
    # [1] 50.24
    # calculate_circle(4, to='perimeter')
    # [1] 25.12
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `convert_degree` 能夠將輸入的溫度度數依照參數 `from` 與 `to` 在攝氏與華氏之間轉換。
#
# \begin{equation}
# Fahrenheit_{(^{\circ} F)} = Celsius_{(^{\circ} C)} \times \frac{9}{5} + 32 \\
# Celsius_{(^{\circ} C)} =  (Fahrenheit_{(^{\circ} F)} - 32) \times \frac{5}{9}
# \end{equation}
#
# - 預期輸入：一個數值向量、兩個文字向量。
# - 預期輸出：一個數值向量。

# %%
convert_degree <- function(x, from, to) {
    # convert_degree(100, from='Celsius', to='Fahrenheit')
    # [1] 212.0
    # convert_degree(0, from='Celsius', to='Fahrenheit')
    # [1] 32.0
    # convert_degree(212, from='Fahrenheit', to='Celsius')
    # [1] 100.0
    # convert_degree(32, from='Fahrenheit', to='Celsius')
    # [1] 0.0
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `get_bmi_category` 能夠將輸入的身高（公分）、體重（公斤）換算為 BMI 類別。
#
# \begin{equation}
# BMI = \frac{weight_{kg}}{height_{m}^2}
# \end{equation}
#
# <https://en.wikipedia.org/wiki/Body_mass_index>
#
# - 預期輸入：兩個數值向量。
# - 預期輸出：一個文字向量。

# %%
get_bmi_category <- function(height, weight) {
    # get_bmi_category(170, 50)
    # [1] 'Underweight'
    # get_bmi_category(170, 60)
    # [1] 'Normal'
    # get_bmi_category(206, 113)
    # [1] 'Overweight'
    # get_bmi_category(216, 147)
    # [1] 'Obese'
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `fizz` 依據是否為 3 的倍數回傳對應文字向量，如果是 3 的倍數輸出 `"Fizz"`，否則將輸入的數字直接輸出。
#
# - 預期輸入：一個數值向量。
# - 預期輸出：一個文字向量或一個數值向量。

# %%
fizz <- function(x) {
    # fizz(3)
    # [1] 'Fizz'
    # fizz(6)
    # [1] 'Fizz'
    # fizz(7)
    # [1] 7
    # fizz(8)
    # [1] 8
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `fizz_buzz` 依據是否為 3、5 或 15 的倍數回傳對應文字向量，如果是 3 的倍數輸出 `"Fizz"`，如果是 5 的倍數輸出 `"Buzz"`，如果是 15 的倍數輸出 `"Fizz Buzz"`，否則將輸入的數字直接輸出。
#
# - 預期輸入：一個數值向量。
# - 預期輸出：一個文字向量或一個數值向量。

# %%
fizz_buzz <- function(x) {
    # fizz_buzz(3)
    # [1] 'Fizz'
    # fizz_buzz(5)
    # [1] 'Buzz'
    # fizz_buzz(15)
    # [1] 'Fizz Buzz'
    # fizz_buzz(16)
    # [1] 16
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `filter_even_and_sum` 能將介於 `a` 與 `b` 之間的偶數挑出來加總後輸出，其中 $a \leq b$。
#
# - 預期輸入：兩個數值向量。
# - 預期輸出：一個數值向量。

# %%
filter_even_and_sum <- function(a, b) {
    # filter_even_and_sum(2, 4)
    # [1] 6
    # filter_even_and_sum(1, 5)
    # [1] 6
    # filter_even_and_sum(2, 10)
    # [1] 30
    # filter_even_and_sum(1, 11)
    # [1] 30
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `filter_negative_and_sum` 能將 `list` 中的負數挑出來加總後輸出。
#
# - 預期輸入：一個清單 `list`。
# - 預期輸出：一個數值向量。

# %%
filter_negative_and_sum <- function(x) {
    # filter_negative_and_sum(list(-5, 5, -6, 6))
    # [1] -11
    # filter_negative_and_sum(list(-5,-5, -6, -6))
    # [1] -22
    # filter_negative_and_sum(list(5, 5, 6, 6))
    # [1] 0
    # filter_negative_and_sum(list(-5, -5, 6, 6))
    # [1] -10
    # filter_negative_and_sum(list(5, 5, -6, -6))
    # [1] -12
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `get_factors` 能夠輸出一個正整數的所有因數。
#
# - 預期輸入：一個數值向量。
# - 預期輸出：一個數值向量。

# %%
get_factors <- function(x) {
    # get_factors(1)
    # [1] 1
    # get_factors(2)
    # [1] 1 2
    # get_factors(3)
    # [1] 1 3
    # get_factors(4)
    # [1] 1 2 4
    # get_factors(5)
    # [1] 1 5
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `is_prime` 能夠判斷輸入的正整數是否為質數（恰好有兩個因數 1 與自身的正整數）。
#
# - 預期輸入：一個數值向量。
# - 預期輸出：一個邏輯向量。

# %%
is_prime <- function(x) {
    # is_prime(1)
    # [1] FALSE
    # is_prime(2)
    # [1] TRUE
    # is_prime(3)
    # [1] TRUE
    # is_prime(4)
    # [1] FALSE
    # is_prime(5)
    # [1] TRUE
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `filter_primes` 能將介於 `a` 與 `b` 之間的質數挑出來加總後輸出，其中 $a \leq b$。
#
# - 預期輸入：兩個數值向量。
# - 預期輸出：一個數值向量。

# %%
filter_primes <- function(a, b) {
    # filter_primes(1, 5)
    # [1] 2 3 5
    # filter_primes(1, 10)
    # [1] 2 3 5 7
    # filter_primes(1, 15)
    # [1] 2 3 5 7 11 13
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `count_vowels` 能計算輸入英文單字中的母音個數有幾個。
#
# - 預期輸入：一個文字向量。
# - 預期輸出：一個數值向量。

# %%
count_vowels <- function(x) {
    # count_vowels("Anakin")
    # [1] 3
    # count_vowels("Luke")
    # [1] 2
    # count_vowels("Skywalker")
    # [1] 2
    # count_vowels("R")
    # [1] 0
    # count_vowels("R Language")
    # [1] 4
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `reverse_vowels` 能將輸入英文單字中的母音做大小寫的調換。
#
# - 預期輸入：一個文字向量。
# - 預期輸出：一個文字向量。

# %%
reverse_vowels <- function(x) {
    # reverse_vowels("Anakin")
    # [1] "anAkIn"
    # reverse_vowels("Luke")
    # [1] "LUkE"
    # reverse_vowels("Skywalker")
    # [1] "SkywAlkEr"
    # reverse_vowels("R")
    # [1] "R"
    # reverse_vowels("R Language")
    # [1] "R LAngUAgE"
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `uppercase_firstname` 能夠將輸入姓名中的「名字」部分轉換為大寫輸出。
#
# - 預期輸入：一個文字向量。
# - 預期輸出：一個文字向量。

# %%
uppercase_firstname <- function(x) {
    # uppercase_firstname('Luke Skywalker')
    # [1] 'LUKE'
    # uppercase_firstname('Anakin Skywalker')
    # [1] 'ANAKIN'
    # uppercase_firstname(c('Luke Skywalker', 'Anakin Skywalker'))
    # [1] 'LUKE' 'ANAKIN'
    # uppercase_firstname(c('Luke Skywalker', 'Anakin Skywalker', 'Darth Vadar'))
    # [1] 'LUKE' 'ANAKIN' 'DARTH'
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 執行測試
#
# Kernel -> Restart & Run All -> Restart and Run All Cells.

# %%
test_calculate_circle <- tryCatch({
    test_that("test_calculate_circle", {
        expect_equal(calculate_circle(3, to='area'), 28.26)
        expect_equal(calculate_circle(3, to='perimeter'), 18.84)
        expect_equal(calculate_circle(4, to='area'), 50.24)
        expect_equal(calculate_circle(4, to='perimeter'), 25.12)
    })
    }, error = function(e) {
        FALSE
})
test_convert_degree <- tryCatch({
    test_that("test_convert_degree", {
        expect_equal(convert_degree(100, from='Celsius', to='Fahrenheit'), 212.0)
        expect_equal(convert_degree(0, from='Celsius', to='Fahrenheit'), 32.0)
        expect_equal(convert_degree(212, from='Fahrenheit', to='Celsius'), 100.0)
        expect_equal(convert_degree(32, from='Fahrenheit', to='Celsius'), 0.0)
    })
    }, error = function(e) {
        FALSE
})
test_get_bmi_category <- tryCatch({
    test_that("test_get_bmi_category", {
        expect_equal(get_bmi_category(170, 50), 'Underweight')
        expect_equal(get_bmi_category(170, 60), 'Normal')
        expect_equal(get_bmi_category(206, 113), 'Overweight')
        expect_equal(get_bmi_category(216, 147), 'Obese')
    })
    }, error = function(e) {
        FALSE
})
test_fizz <- tryCatch({
    test_that("test_fizz", {
        expect_equal(fizz(3), 'Fizz')
        expect_equal(fizz(6), 'Fizz')
        expect_equal(fizz(7), 7)
        expect_equal(fizz(8), 8)
    })
    }, error = function(e) {
        FALSE
})
test_fizz_buzz <- tryCatch({
    test_that("test_fizz", {
        expect_equal(fizz_buzz(3), 'Fizz')
        expect_equal(fizz_buzz(5), 'Buzz')
        expect_equal(fizz_buzz(15), 'Fizz Buzz')
        expect_equal(fizz_buzz(16), 16)
    })
    }, error = function(e) {
        FALSE
})

test_filter_even_and_sum <- tryCatch({
    test_that("test_filter_even_and_sum", {
        expect_equal(filter_even_and_sum(2, 4), 6)
        expect_equal(filter_even_and_sum(1, 5), 6)
        expect_equal(filter_even_and_sum(2, 10), 30)
        expect_equal(filter_even_and_sum(1, 11), 30)
    })
    }, error = function(e) {
        FALSE
})

test_filter_negative_and_sum <- tryCatch({
    test_that("test_filter_negative_and_sum", {
        expect_equal(filter_negative_and_sum(list(-5, 5, -6, 6)), -11)
        expect_equal(filter_negative_and_sum(list(-5,-5, -6, -6)), -22)
        expect_equal(filter_negative_and_sum(list(5, 5, 6, 6)), 0)
        expect_equal(filter_negative_and_sum(list(-5, -5, 6, 6)), -10)
        expect_equal(filter_negative_and_sum(list(5, 5, -6, -6)), -12)
    })
    }, error = function(e) {
        FALSE
})
test_get_factors <- tryCatch({
    test_that("test_get_factors", {
        expect_equal(get_factors(1), 1)
        expect_equal(get_factors(2), c(1, 2))
        expect_equal(get_factors(3), c(1, 3))
        expect_equal(get_factors(4), c(1, 2, 4))
        expect_equal(get_factors(5), c(1, 5))
    })
    }, error = function(e) {
        FALSE
})
test_is_prime <- tryCatch({
    test_that("test_is_prime", {
        expect_false(is_prime(1))
        expect_true(is_prime(2))
        expect_true(is_prime(3))
        expect_false(is_prime(4))
        expect_true(is_prime(5))
    })
    }, error = function(e) {
        FALSE
})
test_filter_primes <- tryCatch({
    test_that("test_is_prime", {
        expect_equal(filter_primes(1, 5), c(2, 3, 5))
        expect_equal(filter_primes(1, 10), c(2, 3, 5, 7))
        expect_equal(filter_primes(1, 15), c(2, 3, 5, 7, 11, 13))
    })
    }, error = function(e) {
        FALSE
})
test_count_vowels <- tryCatch({
    test_that("test_count_vowels", {
        expect_equal(count_vowels("Anakin"), 3)
        expect_equal(count_vowels("Luke"), 2)
        expect_equal(count_vowels("Skywalker"), 2)
        expect_equal(count_vowels("R"), 0)
        expect_equal(count_vowels("R Language"), 4)
    })
    }, error = function(e) {
        FALSE
})
test_reverse_vowels <- tryCatch({
    test_that("test_reverse_vowels", {
        expect_equal(reverse_vowels("Anakin"), "anAkIn")
        expect_equal(reverse_vowels("Luke"), "LUkE")
        expect_equal(reverse_vowels("Skywalker"), "SkywAlkEr")
        expect_equal(reverse_vowels("R"), "R")
        expect_equal(reverse_vowels("R Language"), "R LAngUAgE")
    })
    }, error = function(e) {
        FALSE
})
test_uppercase_firstname <- tryCatch({
    test_that("test_uppercase_firstname", {
        expect_equal(uppercase_firstname('Luke Skywalker'), 'LUKE')
        expect_equal(uppercase_firstname('Anakin Skywalker'), 'ANAKIN')
        expect_equal(uppercase_firstname(c('Luke Skywalker', 'Anakin Skywalker')), c('LUKE', 'ANAKIN'))
        expect_equal(uppercase_firstname(c('Luke Skywalker', 'Anakin Skywalker', 'Darth Vadar')), c('LUKE', 'ANAKIN', 'DARTH'))
    })
    }, error = function(e) {
        FALSE
})
all_tests <- c(test_calculate_circle,
               test_convert_degree,
               test_get_bmi_category,
               test_fizz, test_fizz_buzz,
               test_filter_even_and_sum,
               test_filter_negative_and_sum,
               test_get_factors,
               test_is_prime,
               test_filter_primes,
               test_count_vowels,
               test_reverse_vowels,
               test_uppercase_firstname
              )
passed_tests <- sum(all_tests)
# Out:
# ── Failure (<text>:3:9): test_calculate_circle ─────────────────────────────────
# calculate_circle(3, to = "area") not equal to 28.26.
# target is NULL, current is numeric
#
# ── Failure (<text>:4:9): test_calculate_circle ─────────────────────────────────
# calculate_circle(3, to = "perimeter") not equal to 18.84.
# target is NULL, current is numeric
#
# ── Failure (<text>:5:9): test_calculate_circle ─────────────────────────────────
# calculate_circle(4, to = "area") not equal to 50.24.
# target is NULL, current is numeric
#
# ── Failure (<text>:6:9): test_calculate_circle ─────────────────────────────────
# calculate_circle(4, to = "perimeter") not equal to 25.12.
# target is NULL, current is numeric
#
# ── Failure (<text>:13:9): test_convert_degree ──────────────────────────────────
# convert_degree(100, from = "Celsius", to = "Fahrenheit") not equal to 212.
# target is NULL, current is numeric
#
# ── Failure (<text>:14:9): test_convert_degree ──────────────────────────────────
# convert_degree(0, from = "Celsius", to = "Fahrenheit") not equal to 32.
# target is NULL, current is numeric
#
# ── Failure (<text>:15:9): test_convert_degree ──────────────────────────────────
# convert_degree(212, from = "Fahrenheit", to = "Celsius") not equal to 100.
# target is NULL, current is numeric
#
# ── Failure (<text>:16:9): test_convert_degree ──────────────────────────────────
# convert_degree(32, from = "Fahrenheit", to = "Celsius") not equal to 0.
# target is NULL, current is numeric
#
# ── Failure (<text>:23:9): test_get_bmi_category ────────────────────────────────
# get_bmi_category(170, 50) not equal to "Underweight".
# target is NULL, current is character
#
# ── Failure (<text>:24:9): test_get_bmi_category ────────────────────────────────
# get_bmi_category(170, 60) not equal to "Normal".
# target is NULL, current is character
#
# ── Failure (<text>:25:9): test_get_bmi_category ────────────────────────────────
# get_bmi_category(206, 113) not equal to "Overweight".
# target is NULL, current is character
#
# ── Failure (<text>:26:9): test_get_bmi_category ────────────────────────────────
# get_bmi_category(216, 147) not equal to "Obese".
# target is NULL, current is character
#
# ── Failure (<text>:33:9): test_fizz ────────────────────────────────────────────
# fizz(3) not equal to "Fizz".
# target is NULL, current is character
#
# ── Failure (<text>:34:9): test_fizz ────────────────────────────────────────────
# fizz(6) not equal to "Fizz".
# target is NULL, current is character
#
# ── Failure (<text>:35:9): test_fizz ────────────────────────────────────────────
# fizz(7) not equal to 7.
# target is NULL, current is numeric
#
# ── Failure (<text>:36:9): test_fizz ────────────────────────────────────────────
# fizz(8) not equal to 8.
# target is NULL, current is numeric
#
# ── Failure (<text>:43:9): test_fizz ────────────────────────────────────────────
# fizz_buzz(3) not equal to "Fizz".
# target is NULL, current is character
#
# ── Failure (<text>:44:9): test_fizz ────────────────────────────────────────────
# fizz_buzz(5) not equal to "Buzz".
# target is NULL, current is character
#
# ── Failure (<text>:45:9): test_fizz ────────────────────────────────────────────
# fizz_buzz(15) not equal to "Fizz Buzz".
# target is NULL, current is character
#
# ── Failure (<text>:46:9): test_fizz ────────────────────────────────────────────
# fizz_buzz(16) not equal to 16.
# target is NULL, current is numeric
#
# ── Failure (<text>:54:9): test_filter_even_and_sum ─────────────────────────────
# filter_even_and_sum(2, 4) not equal to 6.
# target is NULL, current is numeric
#
# ── Failure (<text>:55:9): test_filter_even_and_sum ─────────────────────────────
# filter_even_and_sum(1, 5) not equal to 6.
# target is NULL, current is numeric
#
# ── Failure (<text>:56:9): test_filter_even_and_sum ─────────────────────────────
# filter_even_and_sum(2, 10) not equal to 30.
# target is NULL, current is numeric
#
# ── Failure (<text>:57:9): test_filter_even_and_sum ─────────────────────────────
# filter_even_and_sum(1, 11) not equal to 30.
# target is NULL, current is numeric
#
# ── Failure (<text>:65:9): test_filter_negative_and_sum ─────────────────────────
# filter_negative_and_sum(list(-5, 5, -6, 6)) not equal to -11.
# target is NULL, current is numeric
#
# ── Failure (<text>:66:9): test_filter_negative_and_sum ─────────────────────────
# filter_negative_and_sum(list(-5, -5, -6, -6)) not equal to -22.
# target is NULL, current is numeric
#
# ── Failure (<text>:67:9): test_filter_negative_and_sum ─────────────────────────
# filter_negative_and_sum(list(5, 5, 6, 6)) not equal to 0.
# target is NULL, current is numeric
#
# ── Failure (<text>:68:9): test_filter_negative_and_sum ─────────────────────────
# filter_negative_and_sum(list(-5, -5, 6, 6)) not equal to -10.
# target is NULL, current is numeric
#
# ── Failure (<text>:69:9): test_filter_negative_and_sum ─────────────────────────
# filter_negative_and_sum(list(5, 5, -6, -6)) not equal to -12.
# target is NULL, current is numeric
#
# ── Failure (<text>:76:9): test_get_factors ─────────────────────────────────────
# get_factors(1) not equal to 1.
# target is NULL, current is numeric
#
# ── Failure (<text>:77:9): test_get_factors ─────────────────────────────────────
# get_factors(2) not equal to c(1, 2).
# target is NULL, current is numeric
#
# ── Failure (<text>:78:9): test_get_factors ─────────────────────────────────────
# get_factors(3) not equal to c(1, 3).
# target is NULL, current is numeric
#
# ── Failure (<text>:79:9): test_get_factors ─────────────────────────────────────
# get_factors(4) not equal to c(1, 2, 4).
# target is NULL, current is numeric
#
# ── Failure (<text>:80:9): test_get_factors ─────────────────────────────────────
# get_factors(5) not equal to c(1, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:87:9): test_is_prime ────────────────────────────────────────
# is_prime(1) is not FALSE
#
# `actual` is NULL
# `expected` is a logical vector (FALSE)
#
# ── Failure (<text>:88:9): test_is_prime ────────────────────────────────────────
# is_prime(2) is not TRUE
#
# `actual` is NULL
# `expected` is a logical vector (TRUE)
#
# ── Failure (<text>:89:9): test_is_prime ────────────────────────────────────────
# is_prime(3) is not TRUE
#
# `actual` is NULL
# `expected` is a logical vector (TRUE)
#
# ── Failure (<text>:90:9): test_is_prime ────────────────────────────────────────
# is_prime(4) is not FALSE
#
# `actual` is NULL
# `expected` is a logical vector (FALSE)
#
# ── Failure (<text>:91:9): test_is_prime ────────────────────────────────────────
# is_prime(5) is not TRUE
#
# `actual` is NULL
# `expected` is a logical vector (TRUE)
#
# ── Failure (<text>:98:9): test_is_prime ────────────────────────────────────────
# filter_primes(1, 5) not equal to c(2, 3, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:99:9): test_is_prime ────────────────────────────────────────
# filter_primes(1, 10) not equal to c(2, 3, 5, 7).
# target is NULL, current is numeric
#
# ── Failure (<text>:100:9): test_is_prime ───────────────────────────────────────
# filter_primes(1, 15) not equal to c(2, 3, 5, 7, 11, 13).
# target is NULL, current is numeric
#
# ── Failure (<text>:107:9): test_count_vowels ───────────────────────────────────
# count_vowels("Anakin") not equal to 3.
# target is NULL, current is numeric
#
# ── Failure (<text>:108:9): test_count_vowels ───────────────────────────────────
# count_vowels("Luke") not equal to 2.
# target is NULL, current is numeric
#
# ── Failure (<text>:109:9): test_count_vowels ───────────────────────────────────
# count_vowels("Skywalker") not equal to 2.
# target is NULL, current is numeric
#
# ── Failure (<text>:110:9): test_count_vowels ───────────────────────────────────
# count_vowels("R") not equal to 0.
# target is NULL, current is numeric
#
# ── Failure (<text>:111:9): test_count_vowels ───────────────────────────────────
# count_vowels("R Language") not equal to 4.
# target is NULL, current is numeric
# ── Failure (<text>:118:9): test_reverse_vowels ─────────────────────────────────
# reverse_vowels("Anakin") not equal to "anAkIn".
# target is NULL, current is character
#
# ── Failure (<text>:119:9): test_reverse_vowels ─────────────────────────────────
# reverse_vowels("Luke") not equal to "LUkE".
# target is NULL, current is character
#
# ── Failure (<text>:120:9): test_reverse_vowels ─────────────────────────────────
# reverse_vowels("Skywalker") not equal to "SkywAlkEr".
# target is NULL, current is character
#
# ── Failure (<text>:121:9): test_reverse_vowels ─────────────────────────────────
# reverse_vowels("R") not equal to "R".
# target is NULL, current is character
#
# ── Failure (<text>:122:9): test_reverse_vowels ─────────────────────────────────
# reverse_vowels("R Language") not equal to "R LAngUAgE".
# target is NULL, current is character
#
# ── Failure (<text>:129:9): test_uppercase_firstname ────────────────────────────
# uppercase_firstname("Luke Skywalker") not equal to "LUKE".
# target is NULL, current is character
#
# ── Failure (<text>:130:9): test_uppercase_firstname ────────────────────────────
# uppercase_firstname("Anakin Skywalker") not equal to "ANAKIN".
# target is NULL, current is character
#
# ── Failure (<text>:131:9): test_uppercase_firstname ────────────────────────────
# uppercase_firstname(c("Luke Skywalker", "Anakin Skywalker")) not equal to c("LUKE", "ANAKIN").
# target is NULL, current is character
#
# ── Failure (<text>:132:9): test_uppercase_firstname ────────────────────────────
# uppercase_firstname(c("Luke Skywalker", "Anakin Skywalker", "Darth Vadar")) not equal to c("LUKE", "ANAKIN", "DARTH").
# target is NULL, current is character

# %%
sprintf("在 %s 題練習中，您總共答對了 %s 題。", length(all_tests), passed_tests)
# Out:
# [1] "在 13 題練習中，您總共答對了 0 題。"
