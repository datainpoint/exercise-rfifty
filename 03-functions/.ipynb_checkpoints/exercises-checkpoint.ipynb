# %% [markdown]
# # R 語言的五十道練習
#
# > 函數
#
# [數據交點](https://www.datainpoint.com/) | 郭耀仁 <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 第一個程式碼儲存格會將可能用得到的套件以及單元測試 `testthat` 載入。
# - 如果練習題需要載入檔案，檔案與練習題存放在同個資料夾中，意即我們可以指定工作目錄來載入。
# - 練習題已經定義好函數的名稱以及參數名稱，我們只需要寫作主體。
# - 函數名稱下面幾行的註解部分是在描述測試如何進行。
# - 觀察函數名稱下面幾行的註解部分能夠暸解輸入以及預期輸出之間的關係，幫助我們更暸解題目。
# - 在 `### BEGIN SOLUTION` 與 `### END SOLUTION` 這兩個單行註解之間撰寫函數的主體。
# - 可以先在 RStudio 寫出跟預期結果相同的程式後再複製貼上到練習題。
# - 執行測試的方式為點選上方選單的 Kernel -> Restart & Run All -> Restart and Run All Cells。
# - 可以每寫一題就執行測試，也可以全部寫完再執行測試。
# - 練習題閒置超過 10 分鐘會自動斷線，這時只要重新點選練習題連結即可重新啟動。

# %%
library("testthat")

# %% [markdown]
# ## 自行定義函數 `multiply` 能夠回傳兩數相乘的結果。
#
# - 預期輸入：兩個數值向量。
# - 預期輸出：一個數值向量。

# %%
multiply <- function(a, b) {
    # multiply(5, 6)
    # 30
    # multiply(6, 7)
    # 42
    # multiply(4, 7)
    # 28
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `power(a, b)` 能夠回傳以 `a` 為底數、`b` 為指數的結果。
#
# - 預期輸入：兩個數值向量。
# - 預期輸出：一個數值向量。

# %%
power <- function(a, b) {
    # power(3, 2)
    # 9
    # power(3, 3)
    # 27
    # power(3, 4)
    # 81
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `celsius_to_fahrenheit` 能夠將攝氏溫度轉換為華氏溫度。
#
# \begin{equation}
# Fahrenheit_{(^{\circ} F)} = Celsius_{(^{\circ} C)} \times \frac{9}{5} + 32
# \end{equation}
#
# - 預期輸入：一個數值向量。
# - 預期輸出：一個數值向量。

# %%
celsius_to_fahrenheit <- function(d) {
    # celsius_to_fahrenheit(0)
    # 32
    # celsius_to_fahrenheit(100)
    # 212
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `fahrenheit_to_celsius` 能夠將華氏溫度轉換為攝氏溫度。
#
# \begin{equation}
# Celsius_{(^{\circ}C)} =  (Fahrenheit_{(^{\circ}F)} - 32) \times \frac{5}{9}
# \end{equation}
#
# - 預期輸入：一個數值向量。
# - 預期輸出：一個數值向量。

# %%
fahrenheit_to_celsius <- function(d) {
    # fahrenheit_to_celsius(32)
    # 0
    # fahrenheit_to_celsius(212)
    # 100
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `fahrenheit_to_kelvin` 能夠將華氏溫度轉換為絕對溫度。
#
# \begin{equation}
# Kelvin{(K)} =  (Fahrenheit_{(^{\circ}F)} - 32) \times \frac{5}{9} + 273
# \end{equation}
#
# - 預期輸入：一個數值向量。
# - 預期輸出：一個數值向量。

# %%
fahrenheit_to_kelvin <- function(d) {
    # fahrenheit_to_kelvin(32)
    # 273
    # fahrenheit_to_kelvin(212)
    # 373
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `feet_inches_to_cm(a, b)` 能夠將身高為 `a` 呎 `b` 吋的籃球員身高換算為公分單位。
#
# \begin{equation}
# 1 \, \text{feet} =  30.48 \, \text{cm} \\
# 1 \, \text{inch} = 2.54 \, \text{cm}
# \end{equation}
#
# - 預期輸入：兩個數值向量。
# - 預期輸出：一個數值向量。

# %%
feet_inches_to_cm <- function(a, b) {
    # feet_inches_to_cm(6, 7)
    # [1] 200.66
    # feet_inches_to_cm(6, 8)
    # [1] 203.2
    # feet_inches_to_cm(6, 9)
    # [1] 205.74
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `say_hello_to_anyone` 對任何輸入的人名說哈囉。
#
# - 預期輸入：一個文字向量。
# - 預期輸出：一個文字向量。

# %%
say_hello_to_anyone <- function(anyone) {
    # say_hello_to_anyone("World")
    # "Hello, World!"
    # say_hello_to_anyone("John Doe")
    # "Hello, John Doe!"
    # say_hello_to_anyone("Luke Skywalker")
    # "Hello, Luke Skywalker!"
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `is_positive` 判斷輸入的數值是否大於等於零。
#
# - 預期輸入：一個數值向量
# - 預期輸出：一個邏輯向量

# %%
is_positive <- function(x) {
    # is_positive(5566)
    # TRUE
    # is_positive(0)
    # TRUE
    # is_positive(-56)
    # FALSE
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `is_even` 判斷輸入的數值是否為偶數。
#
# - 預期輸入：一個數值向量
# - 預期輸出：一個邏輯向量

# %%
is_even <- function(x) {
    # is_even(0)
    # TRUE
    # is_even(2)
    # TRUE
    # is_even(3)
    # FALSE
    # is_even(5)
    # FALSE
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `is_two_digits` 判斷輸入的數值是否介於 10 與 99 之間。
#
# - 預期輸入：一個數值向量
# - 預期輸出：一個邏輯向量

# %%
is_two_digits <- function(x) {
    # is_two_digits(9)
    # FALSE
    # is_two_digits(100)
    # FALSE
    # is_two_digits(10)
    # TRUE
    # is_two_digits(99)
    # TRUE
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 執行測試
#
# Kernel -> Restart & Run All. -> Restart and Run All Cells.

# %%
test_multiply <- tryCatch({
    test_that("test_multiply", {
        expect_equal(multiply(5, 6), 30)
        expect_equal(multiply(6, 7), 42)
        expect_equal(multiply(4, 7), 28)
    })
    }, error = function(e) {
        FALSE
})
test_power <- tryCatch({
    test_that("test_power", {
        expect_equal(power(3, 2), 9)
        expect_equal(power(3, 3), 27)
        expect_equal(power(3, 4), 81)
    })
    }, error = function(e) {
        FALSE
})
test_celsius_to_fahrenheit <- tryCatch({
    test_that("test_celsius_to_fahrenheit", {
        expect_equal(celsius_to_fahrenheit(0), 32)
        expect_equal(celsius_to_fahrenheit(100), 212)
    })
    }, error = function(e) {
        FALSE
})
test_fahrenheit_to_celsius <- tryCatch({
    test_that("test_fahrenheit_to_celsius", {
        expect_equal(fahrenheit_to_celsius(32), 0)
        expect_equal(fahrenheit_to_celsius(212), 100)
    })
    }, error = function(e) {
        FALSE
})
test_fahrenheit_to_kelvin <- tryCatch({
    test_that("test_fahrenheit_to_kelvin", {
        expect_equal(fahrenheit_to_kelvin(32), 273)
        expect_equal(fahrenheit_to_kelvin(212), 373)
    })
    }, error = function(e) {
        FALSE
})
test_feet_inches_to_cm <- tryCatch({
    test_that("test_feet_inches_to_cm", {
        expect_true(feet_inches_to_cm(6, 7) > 200)
        expect_true(feet_inches_to_cm(6, 8) > 203)
        expect_true(feet_inches_to_cm(6, 9) > 205)
    })
    }, error = function(e) {
        FALSE
})
test_say_hello_to_anyone <- tryCatch({
    test_that("test_say_hello_to_anyone", {
        expect_equal(say_hello_to_anyone("World"), "Hello, World!")
        expect_equal(say_hello_to_anyone("John Doe"), "Hello, John Doe!")
        expect_equal(say_hello_to_anyone("Luke Skywalker"), "Hello, Luke Skywalker!")
    })
    }, error = function(e) {
        FALSE
})
test_is_positive <- tryCatch({
    test_that("test_is_positive", {
        expect_equal(is_positive(5566), TRUE)
        expect_equal(is_positive(0), TRUE)
        expect_equal(is_positive(-56), FALSE)
    })
    }, error = function(e) {
        FALSE
})
test_is_even <- tryCatch({
    test_that("test_is_even", {
        expect_equal(is_even(0), TRUE)
        expect_equal(is_even(2), TRUE)
        expect_equal(is_even(3), FALSE)
        expect_equal(is_even(5), FALSE)
    })
    }, error = function(e) {
        FALSE
})
test_is_two_digits <- tryCatch({
    test_that("test_is_two_digits", {
        expect_equal(is_two_digits(10), TRUE)
        expect_equal(is_two_digits(99), TRUE)
        expect_equal(is_two_digits(9), FALSE)
        expect_equal(is_two_digits(100), FALSE)
    })
    }, error = function(e) {
        FALSE
})
all_tests <- c(test_multiply,
               test_power,
               test_celsius_to_fahrenheit,
               test_fahrenheit_to_celsius,
               test_fahrenheit_to_kelvin,
               test_feet_inches_to_cm,
               test_say_hello_to_anyone,
               test_is_positive,
               test_is_even,
               test_is_two_digits
              )
passed_tests <- sum(all_tests)
# Out:
# ── Failure (<text>:3:9): test_multiply ─────────────────────────────────────────
# multiply(5, 6) not equal to 30.
# target is NULL, current is numeric
#
# ── Failure (<text>:4:9): test_multiply ─────────────────────────────────────────
# multiply(6, 7) not equal to 42.
# target is NULL, current is numeric
#
# ── Failure (<text>:5:9): test_multiply ─────────────────────────────────────────
# multiply(4, 7) not equal to 28.
# target is NULL, current is numeric
#
# ── Failure (<text>:12:9): test_power ───────────────────────────────────────────
# power(3, 2) not equal to 9.
# target is NULL, current is numeric
#
# ── Failure (<text>:13:9): test_power ───────────────────────────────────────────
# power(3, 3) not equal to 27.
# target is NULL, current is numeric
#
# ── Failure (<text>:14:9): test_power ───────────────────────────────────────────
# power(3, 4) not equal to 81.
# target is NULL, current is numeric
#
# ── Failure (<text>:21:9): test_celsius_to_fahrenheit ───────────────────────────
# celsius_to_fahrenheit(0) not equal to 32.
# target is NULL, current is numeric
#
# ── Failure (<text>:22:9): test_celsius_to_fahrenheit ───────────────────────────
# celsius_to_fahrenheit(100) not equal to 212.
# target is NULL, current is numeric
#
# ── Failure (<text>:29:9): test_fahrenheit_to_celsius ───────────────────────────
# fahrenheit_to_celsius(32) not equal to 0.
# target is NULL, current is numeric
#
# ── Failure (<text>:30:9): test_fahrenheit_to_celsius ───────────────────────────
# fahrenheit_to_celsius(212) not equal to 100.
# target is NULL, current is numeric
#
# ── Failure (<text>:37:9): test_fahrenheit_to_kelvin ────────────────────────────
# fahrenheit_to_kelvin(32) not equal to 273.
# target is NULL, current is numeric
#
# ── Failure (<text>:38:9): test_fahrenheit_to_kelvin ────────────────────────────
# fahrenheit_to_kelvin(212) not equal to 373.
# target is NULL, current is numeric
#
# ── Failure (<text>:45:9): test_feet_inches_to_cm ───────────────────────────────
# feet_inches_to_cm(6, 7) > 200 is not TRUE
#
# `actual`:
# `expected`: TRUE
#
# ── Failure (<text>:46:9): test_feet_inches_to_cm ───────────────────────────────
# feet_inches_to_cm(6, 8) > 203 is not TRUE
#
# `actual`:
# `expected`: TRUE
#
# ── Failure (<text>:47:9): test_feet_inches_to_cm ───────────────────────────────
# feet_inches_to_cm(6, 9) > 205 is not TRUE
#
# `actual`:
# `expected`: TRUE
#
# ── Failure (<text>:54:9): test_say_hello_to_anyone ─────────────────────────────
# say_hello_to_anyone("World") not equal to "Hello, World!".
# target is NULL, current is character
#
# ── Failure (<text>:55:9): test_say_hello_to_anyone ─────────────────────────────
# say_hello_to_anyone("John Doe") not equal to "Hello, John Doe!".
# target is NULL, current is character
#
# ── Failure (<text>:56:9): test_say_hello_to_anyone ─────────────────────────────
# say_hello_to_anyone("Luke Skywalker") not equal to "Hello, Luke Skywalker!".
# target is NULL, current is character
#
# ── Failure (<text>:63:9): test_is_positive ─────────────────────────────────────
# is_positive(5566) not equal to TRUE.
# target is NULL, current is logical
#
# ── Failure (<text>:64:9): test_is_positive ─────────────────────────────────────
# is_positive(0) not equal to TRUE.
# target is NULL, current is logical
#
# ── Failure (<text>:65:9): test_is_positive ─────────────────────────────────────
# is_positive(-56) not equal to FALSE.
# target is NULL, current is logical
#
# ── Failure (<text>:72:9): test_is_even ─────────────────────────────────────────
# is_even(0) not equal to TRUE.
# target is NULL, current is logical
#
# ── Failure (<text>:73:9): test_is_even ─────────────────────────────────────────
# is_even(2) not equal to TRUE.
# target is NULL, current is logical
#
# ── Failure (<text>:74:9): test_is_even ─────────────────────────────────────────
# is_even(3) not equal to FALSE.
# target is NULL, current is logical
#
# ── Failure (<text>:75:9): test_is_even ─────────────────────────────────────────
# is_even(5) not equal to FALSE.
# target is NULL, current is logical
#
# ── Failure (<text>:82:9): test_is_two_digits ───────────────────────────────────
# is_two_digits(10) not equal to TRUE.
# target is NULL, current is logical
#
# ── Failure (<text>:83:9): test_is_two_digits ───────────────────────────────────
# is_two_digits(99) not equal to TRUE.
# target is NULL, current is logical
#
# ── Failure (<text>:84:9): test_is_two_digits ───────────────────────────────────
# is_two_digits(9) not equal to FALSE.
# target is NULL, current is logical
#
# ── Failure (<text>:85:9): test_is_two_digits ───────────────────────────────────
# is_two_digits(100) not equal to FALSE.
# target is NULL, current is logical

# %%
sprintf("在 %s 題練習中，您總共答對了 %s 題。", length(all_tests), passed_tests)
# Out:
# [1] "在 10 題練習中，您總共答對了 0 題。"
