# %% [markdown]
# # R 語言的 50+ 練習
#
# > 建立清單、資料框儲存異質資料
#
# [數聚點](https://www.datainpoint.com/) | 郭耀仁 <yaojenkuo@datainpoint.com>

# %% [markdown]
# ## 練習題指引
#
# - 第一個程式碼儲存格會將可能用得到的套件以及單元測試 `testthat` 載入。
# - 如果練習題需要載入檔案，檔案與練習題存放在同個資料夾中，意即我們可以指定工作目錄來載入。
# - 練習題已經定義好函數的名稱以及參數名稱，我們只需要寫作主體。
# - 函數名稱下面幾行的註解部分是在描述測試如何進行。
# - 觀察函數名稱下面幾行的註解部分能夠暸解輸入以及預期輸出之間的關係，幫助我們更暸解題目。
# - 在 `### BEGIN SOLUTION` 與 `### END SOLUTION` 這兩個單行註解之間撰寫函數的主體。
# - 可以先在 RStudio 寫出跟預期結果相同的程式後再複製貼上到練習題。
# - 執行測試的方式為點選上方選單的 Kernel -> Restart & Run All -> Restart and Run All Cells。
# - 可以每寫一題就執行測試，也可以全部寫完再執行測試。
# - 練習題閒置超過 10 分鐘會自動斷線，這時只要重新點選練習題連結即可重新啟動。

# %%
library("testthat")

# %% [markdown]
# ## 自行定義函數 `get_first_five_primes` 能夠以清單資料結構回傳前五個質數。
#
# - 預期輸入：無。
# - 預期輸出：一個長度 5 的清單。

# %%
get_first_five_primes <- function() {
    # first_five_primes <- get_first_five_primes()
    # first_five_primes[[1]]
    # [1] 2
    # first_five_primes[[2]]
    # [1] 3
    # first_five_primes[[3]]
    # [1] 5
    # first_five_primes[[4]]
    # [1] 7
    # first_five_primes[[5]]
    # [1] 11
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `get_first_five_primes_with_names` 能夠回傳前五個質數並用命名的清單儲存。
#
# - 預期輸入：無。
# - 預期輸出：一個長度 5 的命名清單。

# %%
get_first_five_primes_with_names <- function() {
    # first_five_primes_with_names <- get_first_five_primes_with_names()
    # first_five_primes_with_names["first"]
    # [1] 2
    # first_five_primes_with_names["second"]
    # [1] 3
    # first_five_primes_with_names["third"]
    # [1] 5
    # first_five_primes_with_names["fourth"]
    # [1] 7
    # first_five_primes_with_names["fifth"]
    # [1] 11
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `get_dark_knight` 能夠回傳「黑暗騎士」的電影資訊並用命名清單儲存。
#
# - 預期輸入：無。
# - 預期輸出：一個長度 3 的命名清單。

# %%
get_dark_knight <- function() {
    # dark_knight <- get_dark_knight()
    # dark_knight[["title"]]
    # [1] "The Dark Knight"
    # dark_knight[["release_year"]]
    # [1] 2008
    # dark_knight[["imdb_rating"]]
    # [1] 9.0
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `get_batman_trilogy_column_wise` 能夠回傳蝙蝠俠三部曲的電影資訊，以電影名稱、上映年份與 IMDb 評等作命名清單儲存。
#
# - 預期輸入：無。
# - 預期輸出：一個長度 3 的命名清單。

# %%
get_batman_trilogy_column_wise <- function() {
    # batman_trilogy_column_wise <- get_batman_trilogy_column_wise()
    # batman_trilogy_column_wise[["title"]]
    # [1] "Batman Begins"         "The Dark Knight"       "The Dark Knight Rises"
    # batman_trilogy_column_wise[["release_year"]]
    # [1] 2005 2008 2012
    # batman_trilogy_column_wise[["imdb_rating"]]
    # [1] 8.2 9.0 8.4
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `get_batman_trilogy_row_wise` 能夠回傳蝙蝠俠三部曲的電影資訊，以集數作為清單的索引儲存。
#
# - 預期輸入：無。
# - 預期輸出：一個長度 3 的清單。

# %%
get_batman_trilogy_row_wise <- function() {
    # batman_trilogy_row_wise <- get_batman_trilogy_row_wise()
    # batman_trilogy_row_wise[[1]]
    # $title
    # [1] "Batman Begins"

    # $release_year
    # [1] 2005

    # $imdb_rating
    # [1] 8.2
    #
    # batman_trilogy_row_wise[[2]]
    # $title
    # [1] "The Dark Knight"

    # $release_year
    # [1] 2008

    # $imdb_rating
    # [1] 9
    #
    # batman_trilogy_row_wise[[3]]
    # $title
    # [1] "The Dark Knight Rises"

    # $release_year
    # [1] 2012

    # $imdb_rating
    # [1] 8.4
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `create_lord_of_the_rings` 以資料框回傳魔戒三部曲電影資訊。
#
# - 預期輸入：無。
# - 預期輸出：一個外型 `(3, 4)` 的資料框。
#
# ```
#   episode                      title release_year      director
# 1       1 The Fellowship of the Ring         2001 Peter Jackson
# 2       2             The Two Towers         2002 Peter Jackson
# 3       3     The Return of the King         2003 Peter Jackson
# ```

# %%
create_lord_of_the_rings <- function() {
    # lord_of_the_rings <- create_lord_of_the_rings()
    # lord_of_the_rings
    #   episode                      title release_year      director
    # 1       1 The Fellowship of the Ring         2001 Peter Jackson
    # 2       2             The Two Towers         2002 Peter Jackson
    # 3       3     The Return of the King         2003 Peter Jackson
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 承上題，自行定義函數 `add_imdb_rating` 將 IMDb 評等 `c(8.8, 8.7, 8.9)` 加入到前一題所輸出的資料框成為一個新欄位 `imdb_rating`。
#
# - 預期輸入：一個外型 `(3, 4)` 的資料框。
# - 預期輸出：一個外型 `(3, 5)` 的資料框。
#
# ```
#   episode                      title release_year      director imdb_rating
# 1       1 The Fellowship of the Ring         2001 Peter Jackson         8.8
# 2       2             The Two Towers         2002 Peter Jackson         8.7
# 3       3     The Return of the King         2003 Peter Jackson         8.9
# ```

# %%
add_imdb_rating <- function(df) {
    # lord_of_the_rings <- create_lord_of_the_rings()
    # add_imdb_rating(lord_of_the_rings)
    #   episode                      title release_year      director imdb_rating
    # 1       1 The Fellowship of the Ring         2001 Peter Jackson         8.8
    # 2       2             The Two Towers         2002 Peter Jackson         8.7
    # 3       3     The Return of the King         2003 Peter Jackson         8.9
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `create_dark_knight` 以資料框回傳黑暗騎士三部曲電影資訊。
#
# - 預期輸入：無。
# - 預期輸出：一個外型 `(3, 5)` 的資料框。
#
# ```
#   episode                 title release_year          director imdb_rating
# 1       1         Batman Begins         2005 Christopher Nolan         8.2
# 2       2       The Dark Knight         2008 Christopher Nolan         9.0
# 3       3 The Dark Knight Rises         2012 Christopher Nolan         8.4
# ```

# %%
create_dark_knight <- function() {
    # dark_knight <- create_dark_knight()
    # dark_knight
    #   episode                 title release_year          director imdb_rating
    # 1       1         Batman Begins         2005 Christopher Nolan         8.2
    # 2       2       The Dark Knight         2008 Christopher Nolan         9.0
    # 3       3 The Dark Knight Rises         2012 Christopher Nolan         8.4
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 承上題，自行定義函數 `filter_the_best_episode` 將資料框中的二部曲 "The Dark Knight" 篩選出成為一個新的資料框。
#
# - 預期輸入：一個外型 `(3, 5)` 的資料框。
# - 預期輸出：一個外型 `(1, 5)` 的資料框。
#
# ```
#   episode           title release_year          director imdb_rating
# 2       2 The Dark Knight         2008 Christopher Nolan           9
# ```

# %%
filter_the_best_episode <- function(df) {
    # dark_knight <- create_dark_knight()
    # filter_the_best_episode(dark_knight)
    #   episode           title release_year          director imdb_rating
    # 2       2 The Dark Knight         2008 Christopher Nolan           9
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 自行定義函數 `create_avengers` 以資料框回傳復仇者聯盟四部曲的電影資訊。
#
# - 預期輸入：無。
# - 預期輸出：一個外型 `(4, 5)` 的資料框。
#
# ```
#   episode                   title release_year      director imdb_rating
# 1       1            The Avengers         2012   Joss Whedon         8.0
# 2       2 Avengers: Age of Ultron         2015   Joss Whedon         7.3
# 3       3  Avengers: Infinity War         2018 Anthony Russo         8.4
# 4       4       Avengers: Endgame         2019 Anthony Russo         8.4
# ```

# %%
create_avengers <- function() {
    # avengers <- create_avengers()
    # avengers
    #   episode                   title release_year      director imdb_rating
    # 1       1            The Avengers         2012   Joss Whedon         8.0
    # 2       2 Avengers: Age of Ultron         2015   Joss Whedon         7.3
    # 3       3  Avengers: Infinity War         2018 Anthony Russo         8.4
    # 4       4       Avengers: Endgame         2019 Anthony Russo         8.4
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 承上題，自行定義函數 `filter_the_worst_episode` 將資料框中的 "Avengers: Age of Ultron" 篩選出成為一個新的資料框。
#
# - 預期輸入：一個外型 `(4, 5)` 的資料框。
# - 預期輸出：一個外型 `(1, 5)` 的資料框。
#
# ```
#   episode                   title release_year    director imdb_rating
# 2       2 Avengers: Age of Ultron         2015 Joss Whedon         7.3
# ```

# %%
filter_the_worst_episode <- function(df) {
    # avengers <- create_avengers()
    # filter_the_worst_episode(avengers)
    #   episode                   title release_year      director imdb_rating
    # 2       2 Avengers: Age of Ultron         2015   Joss Whedon         7.3
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 承上上題，自行定義函數 `remove_the_worst_episode` 將資料框中的 "Avengers: Age of Ultron" 刪除。
#
# - 預期輸入：一個外型 `(4, 5)` 的資料框。
# - 預期輸出：一個外型 `(3, 5)` 的資料框。
#
# ```
#   episode                  title release_year      director imdb_rating
# 1       1           The Avengers         2012   Joss Whedon         8.0
# 3       3 Avengers: Infinity War         2018 Anthony Russo         8.4
# 4       4      Avengers: Endgame         2019 Anthony Russo         8.4
# ```

# %%
remove_the_worst_episode <- function(df) {
    # avengers <- create_avengers()
    # remove_the_worst_episode(avengers)
    #   episode                   title release_year      director imdb_rating
    # 1       1            The Avengers         2012   Joss Whedon         8.0
    # 3       3  Avengers: Infinity War         2018 Anthony Russo         8.4
    # 4       4       Avengers: Endgame         2019 Anthony Russo         8.4
    ### BEGIN SOLUTION
    
    ### END SOLUTION
}

# %% [markdown]
# ## 執行測試
#
# Kernel -> Restart & Run All. -> Restart and Run All Cells.

# %%
test_get_first_five_primes <- tryCatch({
    test_that("test_get_first_five_primes", {
        expect_equal(length(get_first_five_primes()), 5)
        expect_equal(get_first_five_primes()[[1]], 2)
        expect_equal(get_first_five_primes()[[2]], 3)
        expect_equal(get_first_five_primes()[[3]], 5)
        expect_equal(get_first_five_primes()[[4]], 7)
        expect_equal(get_first_five_primes()[[5]], 11)
    })
    }, error = function(e) {
        FALSE
})
test_get_first_five_primes_with_names <- tryCatch({
    test_that("test_get_first_five_primes_with_names", {
        expect_equal(length(get_first_five_primes_with_names()), 5)
        expect_equal(get_first_five_primes_with_names()[["first"]], 2)
        expect_equal(get_first_five_primes_with_names()[["second"]], 3)
        expect_equal(get_first_five_primes_with_names()[["third"]], 5)
        expect_equal(get_first_five_primes_with_names()[["fourth"]], 7)
        expect_equal(get_first_five_primes_with_names()[["fifth"]], 11)
    })
    }, error = function(e) {
        FALSE
})
test_get_dark_knight <- tryCatch({
    test_that("test_get_dark_knight", {
        expect_equal(length(get_dark_knight()), 3)
        expect_equal(get_dark_knight()[["title"]], "The Dark Knight")
        expect_equal(get_dark_knight()[["release_year"]], 2008)
        expect_equal(get_dark_knight()[["imdb_rating"]], 9.0)
    })
    }, error = function(e) {
        FALSE
})
test_get_batman_trilogy_column_wise <- tryCatch({
    test_that("test_get_batman_trilogy_column_wise", {
        expect_equal(length(get_batman_trilogy_column_wise()), 3)
        expect_equal(get_batman_trilogy_column_wise()[["title"]], c("Batman Begins", "The Dark Knight", "The Dark Knight Rises"))
        expect_equal(get_batman_trilogy_column_wise()[["release_year"]], c(2005, 2008, 2012))
        expect_equal(get_batman_trilogy_column_wise()[["imdb_rating"]], c(8.2, 9.0, 8.4))
    })
    }, error = function(e) {
        FALSE
})
test_get_batman_trilogy_row_wise <- tryCatch({
    test_that("test_get_batman_trilogy_row_wise", {
        expect_equal(length(get_batman_trilogy_row_wise()), 3)
        expect_equal(get_batman_trilogy_row_wise()[[1]], list(title = "Batman Begins", release_year = 2005, imdb_rating = 8.2))
        expect_equal(get_batman_trilogy_row_wise()[[2]], list(title = "The Dark Knight", release_year = 2008, imdb_rating = 9.0))
        expect_equal(get_batman_trilogy_row_wise()[[3]], list(title = "The Dark Knight Rises", release_year = 2012, imdb_rating = 8.4))
    })
    }, error = function(e) {
        FALSE
})
test_create_lord_of_the_rings <- tryCatch({
    test_that("test_create_lord_of_the_rings", {
        expect_equal(dim(create_lord_of_the_rings()), c(3, 4))
        expect_equal(create_lord_of_the_rings()[["title"]], c("The Fellowship of the Ring", "The Two Towers", "The Return of the King"))
    })
    }, error = function(e) {
        FALSE
})
test_add_imdb_rating <- tryCatch({
    test_that("test_add_imdb_rating", {
        expect_equal(dim(add_imdb_rating(create_lord_of_the_rings())), c(3, 5))
        expect_equal(add_imdb_rating(create_lord_of_the_rings())[["imdb_rating"]], c(8.8, 8.7, 8.9))
    })
    }, error = function(e) {
        FALSE
})
test_create_dark_knight <- tryCatch({
    test_that("test_create_dark_knight", {
        expect_equal(dim(create_dark_knight()), c(3, 5))
        expect_equal(create_dark_knight()[["title"]], c("Batman Begins", "The Dark Knight", "The Dark Knight Rises"))
    })
    }, error = function(e) {
        FALSE
})
test_filter_the_best_episode <- tryCatch({
    test_that("test_filter_the_best_episode", {
        expect_equal(dim(filter_the_best_episode(create_dark_knight())), c(1, 5))
        expect_equal(filter_the_best_episode(create_dark_knight())[["title"]], "The Dark Knight")
    })
    }, error = function(e) {
        FALSE
})
test_create_avengers <- tryCatch({
    test_that("test_create_avengers", {
        expect_equal(dim(create_avengers()), c(4, 5))
        expect_equal(create_avengers()[["title"]], c("The Avengers", "Avengers: Age of Ultron", "Avengers: Infinity War", "Avengers: Endgame"))
    })
    }, error = function(e) {
        FALSE
})
test_filter_the_worst_episode <- tryCatch({
    test_that("test_filter_the_worst_episode", {
        expect_equal(dim(filter_the_worst_episode(create_avengers())), c(1, 5))
        expect_equal(filter_the_worst_episode(create_avengers())[["title"]], "Avengers: Age of Ultron")
    })
    }, error = function(e) {
        FALSE
})
test_remove_the_worst_episode <- tryCatch({
    test_that("test_remove_the_worst_episode", {
        expect_equal(dim(remove_the_worst_episode(create_avengers())), c(3, 5))
        expect_equal(remove_the_worst_episode(create_avengers())[["title"]], c("The Avengers", "Avengers: Infinity War", "Avengers: Endgame"))
    })
    }, error = function(e) {
        FALSE
})
all_tests <- c(test_get_first_five_primes,
               test_get_first_five_primes_with_names,
               test_get_dark_knight,
               test_get_batman_trilogy_column_wise,
               test_get_batman_trilogy_row_wise,
               test_create_lord_of_the_rings,
               test_add_imdb_rating,
               test_create_dark_knight,
               test_filter_the_best_episode,
               test_create_avengers,
               test_filter_the_worst_episode,
               test_remove_the_worst_episode
              )
passed_tests <- sum(all_tests)
# Out:
# ── Failure (<text>:3:9): test_get_first_five_primes ────────────────────────────
# length(get_first_five_primes()) not equal to 5.
# 1/1 mismatches
# [1] 0 - 5 == -5
#
# ── Failure (<text>:4:9): test_get_first_five_primes ────────────────────────────
# get_first_five_primes()[[1]] not equal to 2.
# target is NULL, current is numeric
#
# ── Failure (<text>:5:9): test_get_first_five_primes ────────────────────────────
# get_first_five_primes()[[2]] not equal to 3.
# target is NULL, current is numeric
#
# ── Failure (<text>:6:9): test_get_first_five_primes ────────────────────────────
# get_first_five_primes()[[3]] not equal to 5.
# target is NULL, current is numeric
#
# ── Failure (<text>:7:9): test_get_first_five_primes ────────────────────────────
# get_first_five_primes()[[4]] not equal to 7.
# target is NULL, current is numeric
#
# ── Failure (<text>:8:9): test_get_first_five_primes ────────────────────────────
# get_first_five_primes()[[5]] not equal to 11.
# target is NULL, current is numeric
#
# ── Failure (<text>:15:9): test_get_first_five_primes_with_names ────────────────
# length(get_first_five_primes_with_names()) not equal to 5.
# 1/1 mismatches
# [1] 0 - 5 == -5
#
# ── Failure (<text>:16:9): test_get_first_five_primes_with_names ────────────────
# get_first_five_primes_with_names()[["first"]] not equal to 2.
# target is NULL, current is numeric
#
# ── Failure (<text>:17:9): test_get_first_five_primes_with_names ────────────────
# get_first_five_primes_with_names()[["second"]] not equal to 3.
# target is NULL, current is numeric
#
# ── Failure (<text>:18:9): test_get_first_five_primes_with_names ────────────────
# get_first_five_primes_with_names()[["third"]] not equal to 5.
# target is NULL, current is numeric
#
# ── Failure (<text>:19:9): test_get_first_five_primes_with_names ────────────────
# get_first_five_primes_with_names()[["fourth"]] not equal to 7.
# target is NULL, current is numeric
#
# ── Failure (<text>:20:9): test_get_first_five_primes_with_names ────────────────
# get_first_five_primes_with_names()[["fifth"]] not equal to 11.
# target is NULL, current is numeric
#
# ── Failure (<text>:27:9): test_get_dark_knight ─────────────────────────────────
# length(get_dark_knight()) not equal to 3.
# 1/1 mismatches
# [1] 0 - 3 == -3
#
# ── Failure (<text>:28:9): test_get_dark_knight ─────────────────────────────────
# get_dark_knight()[["title"]] not equal to "The Dark Knight".
# target is NULL, current is character
#
# ── Failure (<text>:29:9): test_get_dark_knight ─────────────────────────────────
# get_dark_knight()[["release_year"]] not equal to 2008.
# target is NULL, current is numeric
#
# ── Failure (<text>:30:9): test_get_dark_knight ─────────────────────────────────
# get_dark_knight()[["imdb_rating"]] not equal to 9.
# target is NULL, current is numeric
#
# ── Failure (<text>:37:9): test_get_batman_trilogy_column_wise ──────────────────
# length(get_batman_trilogy_column_wise()) not equal to 3.
# 1/1 mismatches
# [1] 0 - 3 == -3
#
# ── Failure (<text>:38:9): test_get_batman_trilogy_column_wise ──────────────────
# get_batman_trilogy_column_wise()[["title"]] not equal to c("Batman Begins", "The Dark Knight", "The Dark Knight Rises").
# target is NULL, current is character
#
# ── Failure (<text>:39:9): test_get_batman_trilogy_column_wise ──────────────────
# get_batman_trilogy_column_wise()[["release_year"]] not equal to c(2005, 2008, 2012).
# target is NULL, current is numeric
#
# ── Failure (<text>:40:9): test_get_batman_trilogy_column_wise ──────────────────
# get_batman_trilogy_column_wise()[["imdb_rating"]] not equal to c(8.2, 9, 8.4).
# target is NULL, current is numeric
#
# ── Failure (<text>:47:9): test_get_batman_trilogy_row_wise ─────────────────────
# length(get_batman_trilogy_row_wise()) not equal to 3.
# 1/1 mismatches
# [1] 0 - 3 == -3
#
# ── Failure (<text>:48:9): test_get_batman_trilogy_row_wise ─────────────────────
# get_batman_trilogy_row_wise()[[1]] not equal to list(title = "Batman Begins", release_year = 2005, imdb_rating = 8.2).
# target is NULL, current is list
#
# ── Failure (<text>:49:9): test_get_batman_trilogy_row_wise ─────────────────────
# get_batman_trilogy_row_wise()[[2]] not equal to list(title = "The Dark Knight", release_year = 2008, imdb_rating = 9).
# target is NULL, current is list
#
# ── Failure (<text>:50:9): test_get_batman_trilogy_row_wise ─────────────────────
# get_batman_trilogy_row_wise()[[3]] not equal to list(title = "The Dark Knight Rises", release_year = 2012, imdb_rating = 8.4).
# target is NULL, current is list
#
# ── Failure (<text>:57:9): test_create_lord_of_the_rings ────────────────────────
# dim(create_lord_of_the_rings()) not equal to c(3, 4).
# target is NULL, current is numeric
#
# ── Failure (<text>:58:9): test_create_lord_of_the_rings ────────────────────────
# create_lord_of_the_rings()[["title"]] not equal to c("The Fellowship of the Ring", "The Two Towers", "The Return of the King").
# target is NULL, current is character
#
# ── Failure (<text>:65:9): test_add_imdb_rating ─────────────────────────────────
# dim(add_imdb_rating(create_lord_of_the_rings())) not equal to c(3, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:66:9): test_add_imdb_rating ─────────────────────────────────
# add_imdb_rating(create_lord_of_the_rings())[["imdb_rating"]] not equal to c(8.8, 8.7, 8.9).
# target is NULL, current is numeric
#
# ── Failure (<text>:73:9): test_create_dark_knight ──────────────────────────────
# dim(create_dark_knight()) not equal to c(3, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:74:9): test_create_dark_knight ──────────────────────────────
# create_dark_knight()[["title"]] not equal to c("Batman Begins", "The Dark Knight", "The Dark Knight Rises").
# target is NULL, current is character
#
# ── Failure (<text>:81:9): test_filter_the_best_episode ─────────────────────────
# dim(filter_the_best_episode(create_dark_knight())) not equal to c(1, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:82:9): test_filter_the_best_episode ─────────────────────────
# filter_the_best_episode(create_dark_knight())[["title"]] not equal to "The Dark Knight".
# target is NULL, current is character
#
# ── Failure (<text>:89:9): test_create_avengers ─────────────────────────────────
# dim(create_avengers()) not equal to c(4, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:90:9): test_create_avengers ─────────────────────────────────
# create_avengers()[["title"]] not equal to c(...).
# target is NULL, current is character
#
# ── Failure (<text>:97:9): test_filter_the_worst_episode ────────────────────────
# dim(filter_the_worst_episode(create_avengers())) not equal to c(1, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:98:9): test_filter_the_worst_episode ────────────────────────
# filter_the_worst_episode(create_avengers())[["title"]] not equal to "Avengers: Age of Ultron".
# target is NULL, current is character
#
# ── Failure (<text>:105:9): test_remove_the_worst_episode ───────────────────────
# dim(remove_the_worst_episode(create_avengers())) not equal to c(3, 5).
# target is NULL, current is numeric
#
# ── Failure (<text>:106:9): test_remove_the_worst_episode ───────────────────────
# remove_the_worst_episode(create_avengers())[["title"]] not equal to c("The Avengers", "Avengers: Infinity War", "Avengers: Endgame").
# target is NULL, current is character

# %%
sprintf("在 %s 題練習中，您總共答對了 %s 題。", length(all_tests), passed_tests)
# Out:
# [1] "在 12 題練習中，您總共答對了 0 題。"
